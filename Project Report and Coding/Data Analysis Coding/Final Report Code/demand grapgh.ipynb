# %%
#### Load all types of toronto rooms
# import all modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
# %matplotlib inline
fig1 = plt.figure(figsize=(2, 2), dpi=100)
# %config InlineBackend.figure_format = 'retina'
import datetime
from matplotlib.dates import DateFormatter
from matplotlib.dates import HourLocator
# Import Multiple CSVs and combining them
df= pd.read_csv("C:/Users/fahmida/Desktop/Rental/airbnb/calendar/demanding2.csv") 
print(df)
# Print the summary statistics of the DataFrame
print(df.describe())
# Out:
#     Unnamed: 0  Months  Availability  Number of Listings   \
# 0            1       1             1               342559
# 1            3       2             1               308520
# 2            5       3             1               341479
# 3            7       4             1               333667
# 4            9       5             1               291402
# 5           11       6             1               268083
# 6           13       7             1               308799
# 7           15       8             1               311440
# 8           17       9             1               287421
# 9           19      10             1               330988
# 10          21      11             1               328087
# 11          23      12             1               337871
#
#     Availability_Percentage  Total Posting  Average Price  \
# 0                  0.687635       498170.0     139.997653
# 1                  0.685661       449960.0     139.235318
# 2                  0.685467       498170.0     138.678056
# 3                  0.692112       482100.0     140.784198
# 4                  0.584945       498170.0     143.465123
# 5                  0.556073       482100.0     151.202228
# 6                  0.619867       498170.0     158.356679
# 7                  0.625168       498170.0     165.741607
# 8                  0.596185       482100.0     159.952610
# 9                  0.664408       498170.0     151.077369
# 10                 0.680537       482100.0     148.889169
# 11                 0.678224       498170.0     147.594421
#
#     Availability Percentage
# 0                 68.763474
# 1                 68.566095
# 2                 68.546681
# 3                 69.211159
# 4                 58.494490
# 5                 55.607343
# 6                 61.986671
# 7                 62.516812
# 8                 59.618544
# 9                 66.440773
# 10                68.053723
# 11                67.822430
#        Unnamed: 0     Months  Availability  Number of Listings   \
# count   12.000000  12.000000          12.0            12.000000
# mean    12.000000   6.500000           1.0        315859.666667
# std      7.211103   3.605551           0.0         24049.156059
# min      1.000000   1.000000           1.0        268083.000000
# 25%      6.500000   3.750000           1.0        304240.500000
# 50%     12.000000   6.500000           1.0        319763.500000
# 75%     17.500000   9.250000           1.0        334718.000000
# max     23.000000  12.000000           1.0        342559.000000
#
#        Availability_Percentage  Total Posting  Average Price  \
# count                12.000000      12.000000      12.000000
# mean                  0.646357  488795.833333     148.747869
# std                   0.047646   14468.409763       8.940444
# min                   0.556073  449960.000000     138.678056
# 25%                   0.613946  482100.000000     140.587562
# 50%                   0.671316  498170.000000     148.241795
# 75%                   0.685515  498170.000000     152.990841
# max                   0.692112  498170.000000     165.741607
#
#        Availability Percentage
# count                12.000000
# mean                 64.635683
# std                   4.764625
# min                  55.607343
# 25%                  61.394639
# 50%                  67.131602
# 75%                  68.551534
# max                  69.211159

# %%
df=df[['Availability Percentage','Average Price']]

# %%
# Out:
# Vacancy Rate (%)_ Total Apartment         0
# Availability Rate (%)_Total Apartment    16
# Average Rent ($)_ Total Apartment         0
# Median Rent ($)_Total Apartment           0
# % Change_Total Apartment                  2
# Units_Total Apartment                     0
# Vacancy Rate (%)_Bachelor                 0
# Availability Rate (%)_Bachelor           16
# Average Rent ($)_Bachelor                 0
# Median Rent ($)_bachelor                  0
# % Change_Bachelor                         3
# Units_Bachelor                            0
# Vacancy Rate (%)_1 Bed                    0
# Availability Rate (%)_1 Bed              16
# Average Rent ($)_1 Bed                    0
# Median Rent ($)_1 Bed                     0
# % Change_ 1 Bed                           3
# Units_ 1 Bed                              0
# Vacancy Rate (%)_2 Bed                    0
# Availability Rate_2 Bed (%)              16
# Average Rent_2 Bed ($)                    0
# Median Rent_2 Bed ($)                     0
# % Change_2 Bed                            2
# Units_2 Bed                               0
# Vacancy Rate (%)_3+ Bed                   0
# Availability Rate (%)_3+ Bed             16
# Average Rent ($)_3+ Bed                   0
# Median Rent ($)_3+ Bed                    0
# % Change_3+ Bed                           4
# Units_3+ Bed                              0
# dtype: int64
# Shape of Original DataFrame: (29, 30)
# Vacancy Rate (%)_ Total Apartment        0
# Availability Rate (%)_Total Apartment    0
# Average Rent ($)_ Total Apartment        0
# Median Rent ($)_Total Apartment          0
# % Change_Total Apartment                 0
# Units_Total Apartment                    0
# Vacancy Rate (%)_Bachelor                0
# Availability Rate (%)_Bachelor           0
# Average Rent ($)_Bachelor                0
# Median Rent ($)_bachelor                 0
# % Change_Bachelor                        0
# Units_Bachelor                           0
# Vacancy Rate (%)_1 Bed                   0
# Availability Rate (%)_1 Bed              0
# Average Rent ($)_1 Bed                   0
# Median Rent ($)_1 Bed                    0
# % Change_ 1 Bed                          0
# Units_ 1 Bed                             0
# Vacancy Rate (%)_2 Bed                   0
# Availability Rate_2 Bed (%)              0
# Average Rent_2 Bed ($)                   0
# Median Rent_2 Bed ($)                    0
# % Change_2 Bed                           0
# Units_2 Bed                              0
# Vacancy Rate (%)_3+ Bed                  0
# Availability Rate (%)_3+ Bed             0
# Average Rent ($)_3+ Bed                  0
# Median Rent ($)_3+ Bed                   0
# % Change_3+ Bed                          0
# Units_3+ Bed                             0
# dtype: int64

# %%
# Plot Vacancy Rate For All Bed Room Types dataset
ax = df.plot(linewidth=2, fontsize=8)

# Additional customizations
ax.set_xlabel('Month')
ax.legend(fontsize=8)

# Show plot
plt.show()

# %%
# Plot an area chart
ax = df.plot.area(fontsize=8)

# Additional customizations
ax.set_xlabel('Month')
ax.legend(fontsize=8)

# Show plot
plt.show()

# %%
# Import seaborn library
import seaborn as sns

# Get correlation matrix of the meat DataFrame
corr_df1 = df1.corr(method='spearman')

# Customize the heatmap of the corr_meat correlation matrix
sns.heatmap(corr_df1,
            annot=True,
            linewidths=0.4,
            annot_kws={"size": 10})

plt.xticks(rotation=90)
plt.yticks(rotation=0) 
plt.show()

# %%
# Clustered heatmaps
# Import seaborn library
import seaborn as sns

# Get correlation matrix of the DataFrame
corr_df1 = df1.corr(method='pearson')

# Customize the heatmap of the corr_meat correlation matrix and rotate the x-axis labels
fig = sns.clustermap(corr_df1,
                     row_cluster=True,
                     col_cluster=True,
                     figsize=(10, 10))

plt.setp(fig.ax_heatmap.xaxis.get_majorticklabels(), rotation=90)
plt.setp(fig.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()

# %%
# Plot Vacancy Rate For All Bed Room Types dataset
df2=df.drop(["Vacancy Rate (%)_ Total Apartment","Vacancy Rate (%)_Bachelor","Vacancy Rate (%)_1 Bed","Vacancy Rate (%)_2 Bed","Vacancy Rate (%)_3+ Bed","Average Rent ($)_ Total Apartment","Median Rent ($)_Total Apartment", "% Change_Total Apartment", "Units_Total Apartment",    
"Average Rent ($)_Bachelor", "Median Rent ($)_bachelor", "% Change_Bachelor", "Units_Bachelor", "Average Rent ($)_1 Bed","Median Rent ($)_1 Bed","% Change_ 1 Bed", "Units_ 1 Bed",
"Average Rent_2 Bed ($)","Median Rent_2 Bed ($)","% Change_2 Bed" ,"Units_2 Bed", "Average Rent ($)_3+ Bed","Median Rent ($)_3+ Bed","% Change_3+ Bed","Units_3+ Bed"], axis=1)
ax = df2.plot(linewidth=2, fontsize=8)

# Additional customizations
ax.set_xlabel('Date')
ax.legend(fontsize=8)

# Show plot
plt.show()

# %%
# Plot an area chart
ax = df2.plot.area(fontsize=8)

# Additional customizations
ax.set_xlabel('Date')
ax.legend(fontsize=8)

# Show plot
plt.show()

# %%
# Plot the meat data
df2_summary=df2.describe()
ax = df2.plot(fontsize=15, linewidth=2)

# Add x-axis labels
ax.set_xlabel('Date', fontsize=12)

# Add summary table information to the plot
ax.table(cellText=df2_summary.values,
         colWidths = [.5]*len(df2_summary.columns),
         rowLabels=df2_summary.index,
         colLabels=df2_summary.columns,
         loc='top')

# Specify the fontsize and location of your legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fontsize=8)

# Show plot
plt.show()

# %%
# Generate a boxplot
df2.boxplot(fontsize=4.5, vert=True)
plt.show()
