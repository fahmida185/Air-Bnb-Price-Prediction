# %%
# import all modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Import data
print("Reading in data...")
filepath = "C:/Users/fahmida/Desktop/Rental/Permanent Rental/By Times/Primary Rental Comparision(Apartment)/Summary By Room Type/1 Bed Toronto_cleaned.csv"
df= pd.read_csv(filepath, header=0, index_col=None)
# Out:
# Reading in data...

# %%
# Display the first five lines of the DataFrame
print(df.head(5))
# Out:
#            Time  Vacancy Rate (%)  Availability Rate (%) Average Rent ($)  \
# 0  1990 October               0.8                    NaN              559
# 1  1991 October               1.5                    NaN              592
# 2  1992 October               1.9                    NaN              610
# 3  1993 October               1.9                    NaN              627
# 4  1994 October               1.3                    NaN              641
#
#   Median Rent ($)  % Change    Units
# 0             525       NaN  122,211
# 1             560       6.4  122,993
# 2             583       4.3  122,101
# 3             605       4.1  121,695
# 4             625       2.6  123,349

# %%
# Print the data type of each column in discoveries
print(df.dtypes)
# Out:
# Time                      object
# Vacancy Rate (%)         float64
# Availability Rate (%)    float64
# Average Rent ($)          object
# Median Rent ($)           object
# % Change                 float64
# Units                     object
# dtype: object

# %%
# Convert the date column to a datestamp type
df['Time'] = pd.to_datetime(df['Time'])

# %%
# Print the data type of each column in discoveries, again
print(df.dtypes)
# Out:
# Time                     datetime64[ns]
# Vacancy Rate (%)                float64
# Availability Rate (%)           float64
# Average Rent ($)                 object
# Median Rent ($)                  object
# % Change                        float64
# Units                            object
# dtype: object

# %%
# Display the first five lines of the DataFrame
print(df.head(5))
# Out:
#         Time  Vacancy Rate (%)  Availability Rate (%) Average Rent ($)  \
# 0 1990-10-01               0.8                    NaN              559
# 1 1991-10-01               1.5                    NaN              592
# 2 1992-10-01               1.9                    NaN              610
# 3 1993-10-01               1.9                    NaN              627
# 4 1994-10-01               1.3                    NaN              641
#
#   Median Rent ($)  % Change    Units
# 0             525       NaN  122,211
# 1             560       6.4  122,993
# 2             583       4.3  122,101
# 3             605       4.1  121,695
# 4             625       2.6  123,349

# %%
# Plot time series dataset
ax = df.plot(linewidth=2, fontsize=12)

# Additional customizations
ax.set_xlabel('Time')
ax.legend(fontsize=15)

# Show plot
plt.show()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-7-847cd8331f59> in <module>()
#       1 # Plot time series dataset
# ----> 2 ax = df.plot(linewidth=2, fontsize=12)
#       3
#       4 # Additional customizations
#       5 ax.set_xlabel('Time')
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
# Plot time series dataset using the cubehelix color palette
ax1 = df.plot(colormap='cubehelix', fontsize=15)

# Additional customizations
ax1.set_xlabel('Time')
ax1.legend(fontsize=18)

# Show plot
plt.show()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-8-b828bf3d9c8f> in <module>()
#       1 # Plot time series dataset using the cubehelix color palette
# ----> 2 ax1 = df.plot(colormap='cubehelix', fontsize=15)
#       3
#       4 # Additional customizations
#       5 ax1.set_xlabel('Time')
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
# Plot time series dataset using the PuOr color palette
ax3 = df.plot(colormap='PuOr', fontsize=15)

# Additional customizations
ax3.set_xlabel('Time')
ax3.legend(fontsize=18)

# Show plot
plt.show()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-9-6ad778a1b929> in <module>()
#       1 # Plot time series dataset using the PuOr color palette
# ----> 2 ax3 = df.plot(colormap='PuOr', fontsize=15)
#       3
#       4 # Additional customizations
#       5 ax3.set_xlabel('Time')
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
# Plot time series dataset using the cubehelix color palette
ax4 = df.plot(colormap='cubehelix', fontsize=15)

# Additional customizations
ax4.set_xlabel('Time')
ax4.legend(fontsize=18)

# Show plot
plt.show()

# %%
#bytime = df.groupby("Time")
#bytime["Vacancy Rate (%)"].describe()
#bytime["Vacancy Rate (%)"].mean()
df_summary = df.describe()
df_mean=df.mean()
p=mean.transpose()
print(p)
# Plot the meat data
ax = df.plot

# Add x-axis labels
ax.set_xlabel('Time', fontsize=6)

# Add summary table information to the plot
ax.table(cellText=df_mean.values,
         colWidths = [0.15]*len(df_mean.columns),
         rowLabels=df_mean.index,
         colLabels=df_mean.columns,
         loc='top')

# Specify the fontsize and location of your legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=3, fontsize=6)

# Show plot
plt.show()
