# %%
# Import pandas
import numpy as np
import pandas
df = pandas.read_csv('C:/Fahmida/MA.Sc York/Project 6400/Data Files/PE excel sheet.csv')
print(df)
# Convert '?' to NaN
df[df == 'NA'] = np.nan

# Print the number of NaNs
print(df.isnull().sum())

# Print shape of original DataFrame
print("Shape of Original DataFrame: {}".format(df.shape))

# Drop missing values and print shape of new DataFrame
df = df.dropna()

# Print shape of new DataFrame
print("Shape of DataFrame After Dropping All Rows with Missing Values: {}".format(df.shape))

# Import the Imputer module
from sklearn.preprocessing import Imputer
from sklearn.svm import SVC

# Setup the Imputation transformer: imp
imp = Imputer(missing_values='NaN', strategy='most_frequent', axis=0)

# Instantiate the SVC classifier: clf
clf = SVC()

# Setup the pipeline with the required steps: steps
steps = [('imputation', imp),
        ('SVM', clf)]
# Out:
#               Inkjet DOD                           Property of Ink  \
# 0         Thermal Inkjet    Np Ink(Au encapsulated by  hexanehiol)
# 1   Piezoelectric Inkjet    Np Ink(Au encapsulated by  hexanehiol)
# 2                    NaN                                       NaN
# 3                    NaN                                       NaN
# 4                    NaN                                       NaN
# 5                    NaN                                       NaN
# 6                    NaN                                       NaN
# 7                    NaN                                       NaN
# 8                    NaN                                       NaN
# 9                    NaN                                       NaN
# 10                   NaN                                       NaN
# 11                   NaN                                       NaN
# 12                   NaN                                       NaN
# 13                   NaN                                       NaN
# 14                   NaN                                       NaN
# 15                   NaN                                       NaN
# 16                   NaN                                       NaN
# 17                   NaN                                       NaN
# 18                   NaN                                       NaN
# 19                   NaN                                       NaN
# 20                   NaN                                       NaN
# 21                   NaN                                       NaN
# 22                   NaN                                       NaN
# 23                   NaN                                       NaN
# 24                   NaN                                       NaN
# 25                   NaN                                       NaN
# 26                   NaN                                       NaN
# 27                   NaN                                       NaN
# 28                   NaN                                       NaN
# 29                   NaN                                       NaN
# 30  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 31  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 32  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 33  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 34  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 35  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 36  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 37  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 38  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 39  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 40  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 41  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 42  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 43  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 44  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 45  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 46  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 47  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 48  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 49  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
# 50  Piezoelectric Inkjet  Np Ploar Ink(Ag encapsulated by  ligand)
#
#    Ink Hydophobic?  Nozzle Orifice(um)  Nozzle Temp(Deg C)  Jetting Freq(Hz)  \
# 0              Yes                60.0                 NaN            1000.0
# 1              Yes                60.0                 NaN            1000.0
# 2              NaN                 NaN                 NaN               NaN
# 3              NaN                 NaN                 NaN               NaN
# 4              NaN                 NaN                 NaN               NaN
# 5              NaN                 NaN                 NaN               NaN
# 6              NaN                 NaN                 NaN               NaN
# 7              NaN                 NaN                 NaN               NaN
# 8              NaN                 NaN                 NaN               NaN
# 9              NaN                 NaN                 NaN               NaN
# 10             NaN                 NaN                 NaN               NaN
# 11             NaN                 NaN                 NaN               NaN
# 12             NaN                 NaN                 NaN               NaN
# 13             NaN                 NaN                 NaN               NaN
# 14             NaN                 NaN                 NaN               NaN
# 15             NaN                 NaN                 NaN               NaN
# 16             NaN                 NaN                 NaN               NaN
# 17             NaN                 NaN                 NaN               NaN
# 18             NaN                 NaN                 NaN               NaN
# 19             NaN                 NaN                 NaN               NaN
# 20             NaN                 NaN                 NaN               NaN
# 21             NaN                 NaN                 NaN               NaN
# 22             NaN                 NaN                 NaN               NaN
# 23             NaN                 NaN                 NaN               NaN
# 24             NaN                 NaN                 NaN               NaN
# 25             NaN                 NaN                 NaN               NaN
# 26             NaN                 NaN                 NaN               NaN
# 27             NaN                 NaN                 NaN               NaN
# 28             NaN                 NaN                 NaN               NaN
# 29             NaN                 NaN                 NaN               NaN
# 30              No                60.0                30.0            1000.0
# 31              No                60.0                30.0            1000.0
# 32              No                60.0                30.0            1000.0
# 33              No                60.0                30.0            1000.0
# 34              No                60.0                30.0            1000.0
# 35              No                60.0                30.0            1000.0
# 36              No                60.0                30.0            1000.0
# 37              No                60.0                30.0            1000.0
# 38              No                60.0                30.0            1000.0
# 39              No                60.0                30.0            1000.0
# 40              No                60.0                30.0            1000.0
# 41              No                60.0                30.0            1000.0
# 42              No                60.0                30.0            1000.0
# 43              No                60.0                30.0            1000.0
# 44              No                60.0                30.0            1000.0
# 45              No                60.0                30.0            1000.0
# 46              No                60.0                30.0            1000.0
# 47              No                60.0                30.0            1000.0
# 48              No                60.0                30.0            1000.0
# 49              No                60.0                30.0            1000.0
# 50              No                60.0                30.0            1000.0
#
#    Trise(us)  Fall Time(us)  \
# 0    small??            NaN
# 1    small??            NaN
# 2        NaN            NaN
# 3        NaN            NaN
# 4        NaN            NaN
# 5        NaN            NaN
# 6        NaN            NaN
# 7        NaN            NaN
# 8        NaN            NaN
# 9        NaN            NaN
# 10       NaN            NaN
# 11       NaN            NaN
# 12       NaN            NaN
# 13       NaN            NaN
# 14       NaN            NaN
# 15       NaN            NaN
# 16       NaN            NaN
# 17       NaN            NaN
# 18       NaN            NaN
# 19       NaN            NaN
# 20       NaN            NaN
# 21       NaN            NaN
# 22       NaN            NaN
# 23       NaN            NaN
# 24       NaN            NaN
# 25       NaN            NaN
# 26       NaN            NaN
# 27       NaN            NaN
# 28       NaN            NaN
# 29       NaN            NaN
# 30         2            4.0
# 31         3            5.0
# 32         3            5.0
# 33         3            5.0
# 34         3            5.0
# 35         3            5.0
# 36         3            5.0
# 37         3            5.0
# 38         3            5.0
# 39         3            5.0
# 40         3            5.0
# 41         5            5.0
# 42         6            6.0
# 43        10           10.0
# 44         2            2.0
# 45         3            3.0
# 46         4            4.0
# 47         7            7.0
# 48         3            5.0
# 49         3            5.0
# 50       NaN            NaN
#
#    Tdwell(optimum)=At velocity max,at optimum Tdwell Voltage is varied to get jettable window  \
# 0                                              Tdwell
# 1                                              Tdwell
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                 10
# 31                                                  9
# 32                                                  9
# 33                                                  9
# 34                                                  9
# 35                                                  9
# 36                                                 12
# 37                                                 15
# 38                                                 20
# 39                                                  8
# 40                                                 10
# 41                                                 12
# 42                                                 12
# 43                                                 12
# 44                                                 12
# 45                                                 12
# 46                                                 12
# 47                                                 12
# 48                                                  8
# 49                                                  8
# 50                                                NaN
#
#        Techo                   ...                    \
# 0   2*Tdwell                   ...
# 1   2*Tdwell                   ...
# 2        NaN                   ...
# 3        NaN                   ...
# 4        NaN                   ...
# 5        NaN                   ...
# 6        NaN                   ...
# 7        NaN                   ...
# 8        NaN                   ...
# 9        NaN                   ...
# 10       NaN                   ...
# 11       NaN                   ...
# 12       NaN                   ...
# 13       NaN                   ...
# 14       NaN                   ...
# 15       NaN                   ...
# 16       NaN                   ...
# 17       NaN                   ...
# 18       NaN                   ...
# 19       NaN                   ...
# 20       NaN                   ...
# 21       NaN                   ...
# 22       NaN                   ...
# 23       NaN                   ...
# 24       NaN                   ...
# 25       NaN                   ...
# 26       NaN                   ...
# 27       NaN                   ...
# 28       NaN                   ...
# 29       NaN                   ...
# 30        20                   ...
# 31        14                   ...
# 32        14                   ...
# 33        14                   ...
# 34        14                   ...
# 35        14                   ...
# 36        24                   ...
# 37        30                   ...
# 38        40                   ...
# 39        16                   ...
# 40        20                   ...
# 41        24                   ...
# 42        24                   ...
# 43        24                   ...
# 44        24                   ...
# 45        24                   ...
# 46        24                   ...
# 47        24                   ...
# 48        16                   ...
# 49        16                   ...
# 50       NaN                   ...
#
#     Solvent Evaporation at nozzle orifice=output5 depends on it  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#     Interaction Between Substrate and Impinging Drop Drop's Contact Angle  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
# 5                                                NaN                  NaN
# 6                                                NaN                  NaN
# 7                                                NaN                  NaN
# 8                                                NaN                  NaN
# 9                                                NaN                  NaN
# 10                                               NaN                  NaN
# 11                                               NaN                  NaN
# 12                                               NaN                  NaN
# 13                                               NaN                  NaN
# 14                                               NaN                  NaN
# 15                                               NaN                  NaN
# 16                                               NaN                  NaN
# 17                                               NaN                  NaN
# 18                                               NaN                  NaN
# 19                                               NaN                  NaN
# 20                                               NaN                  NaN
# 21                                               NaN                  NaN
# 22                                               NaN                  NaN
# 23                                               NaN                  NaN
# 24                                               NaN                  NaN
# 25                                               NaN                  NaN
# 26                                               NaN                  NaN
# 27                                               NaN                  NaN
# 28                                               NaN                  NaN
# 29                                               NaN                  NaN
# 30                                               NaN                  NaN
# 31                                               NaN                  NaN
# 32                                               NaN                  NaN
# 33                                               NaN                  NaN
# 34                                               NaN                  NaN
# 35                                               NaN                  NaN
# 36                                               NaN                  NaN
# 37                                               NaN                  NaN
# 38                                               NaN                  NaN
# 39                                               NaN                  NaN
# 40                                               NaN                  NaN
# 41                                               NaN                  NaN
# 42                                               NaN                  NaN
# 43                                               NaN                  NaN
# 44                                               NaN                  NaN
# 45                                               NaN                  NaN
# 46                                               NaN                  NaN
# 47                                               NaN                  NaN
# 48                                               NaN                  NaN
# 49                                               NaN                  NaN
# 50                                               NaN                  NaN
#
#     Show Coffie ring effect? Z=Re/Sqt(We), If<2=not Stable  Fluid Type     Ca  \
# 0                        NaN                           NaN   Newtonian  min 0
# 1                        NaN                           NaN   Newtonian  max 4
# 2                        NaN                           NaN         NaN    NaN
# 3                        NaN                           NaN         NaN    NaN
# 4                        NaN                           NaN         NaN    NaN
# 5                        NaN                           NaN         NaN    NaN
# 6                        NaN                           NaN         NaN    NaN
# 7                        NaN                           NaN         NaN    NaN
# 8                        NaN                           NaN         NaN    NaN
# 9                        NaN                           NaN         NaN    NaN
# 10                       NaN                           NaN         NaN    NaN
# 11                       NaN                           NaN         NaN    NaN
# 12                       NaN                           NaN         NaN    NaN
# 13                       NaN                           NaN         NaN    NaN
# 14                       NaN                           NaN         NaN    NaN
# 15                       NaN                           NaN         NaN    NaN
# 16                       NaN                           NaN         NaN    NaN
# 17                       NaN                           NaN         NaN    NaN
# 18                       NaN                           NaN         NaN    NaN
# 19                       NaN                           NaN         NaN    NaN
# 20                       NaN                           NaN         NaN    NaN
# 21                       NaN                           NaN         NaN    NaN
# 22                       NaN                           NaN         NaN    NaN
# 23                       NaN                           NaN         NaN    NaN
# 24                       NaN                           NaN         NaN    NaN
# 25                       NaN                           NaN         NaN    NaN
# 26                       NaN                           NaN         NaN    NaN
# 27                       NaN                           NaN         NaN    NaN
# 28                       NaN                           NaN         NaN    NaN
# 29                       NaN                           NaN         NaN    NaN
# 30                       NaN                           NaN   Newtonian    NaN
# 31                       NaN                           NaN   Newtonian    NaN
# 32                       NaN                           NaN   Newtonian    NaN
# 33                       NaN                           NaN   Newtonian    NaN
# 34                       NaN                           NaN   Newtonian    NaN
# 35                       NaN                           NaN   Newtonian    NaN
# 36                       NaN                           NaN   Newtonian    NaN
# 37                       NaN                           NaN   Newtonian    NaN
# 38                       NaN                           NaN   Newtonian    NaN
# 39                       NaN                           NaN   Newtonian    NaN
# 40                       NaN                           NaN   Newtonian    NaN
# 41                       NaN                           NaN   Newtonian    NaN
# 42                       NaN                           NaN   Newtonian    NaN
# 43                       NaN                           NaN   Newtonian    NaN
# 44                       NaN                           NaN   Newtonian    NaN
# 45                       NaN                           NaN   Newtonian    NaN
# 46                       NaN                           NaN   Newtonian    NaN
# 47                       NaN                           NaN   Newtonian    NaN
# 48                       NaN                           NaN   Newtonian    NaN
# 49                       NaN                           NaN   Newtonian    NaN
# 50                       NaN                           NaN         NaN    NaN
#
#         We  Output1: Drop Quality  Output2: Velocity of Ejected Drop m/s
# 0   min1.5                 Stable                                     NaN
# 1    max15                 Stable                                     NaN
# 2      NaN                    NaN                                     NaN
# 3      NaN                    NaN                                     NaN
# 4      NaN                    NaN                                     NaN
# 5      NaN                    NaN                                     NaN
# 6      NaN                    NaN                                     NaN
# 7      NaN                    NaN                                     NaN
# 8      NaN                    NaN                                     NaN
# 9      NaN                    NaN                                     NaN
# 10     NaN                    NaN                                     NaN
# 11     NaN                    NaN                                     NaN
# 12     NaN                    NaN                                     NaN
# 13     NaN                    NaN                                     NaN
# 14     NaN                    NaN                                     NaN
# 15     NaN                    NaN                                     NaN
# 16     NaN                    NaN                                     NaN
# 17     NaN                    NaN                                     NaN
# 18     NaN                    NaN                                     NaN
# 19     NaN                    NaN                                     NaN
# 20     NaN                    NaN                                     NaN
# 21     NaN                    NaN                                     NaN
# 22     NaN                    NaN                                     NaN
# 23     NaN                    NaN                                     NaN
# 24     NaN                    NaN                                     NaN
# 25     NaN                    NaN                                     NaN
# 26     NaN                    NaN                                     NaN
# 27     NaN                    NaN                                     NaN
# 28     NaN                    NaN                                     NaN
# 29     NaN                    NaN                                     NaN
# 30     NaN                 Stable                                  6.5000
# 31     NaN                 Stable                                  0.0890
# 32     NaN                 Stable                                  0.1560
# 33     NaN                 Stable                                  0.2400
# 34     NaN              Multidrop                                     NaN
# 35     NaN          Drop Breaking                                     NaN
# 36     NaN                 Stable                                     NaN
# 37     NaN            Tailed Drop                                     NaN
# 38     NaN            Tailed Drop                                     NaN
# 39     NaN                 Stable                                  0.2160
# 40     NaN                 Stable                                  0.1728
# 41     NaN                 Stable                                  0.2160
# 42     NaN          Drop Breaking                                     NaN
# 43     NaN          Drop Breaking                                     NaN
# 44     NaN                 Stable                                  0.1800
# 45     NaN                 Stable                                  0.1920
# 46     NaN                 Stable                                  0.2040
# 47     NaN          Drop Breaking                                     NaN
# 48     NaN                 Stable                                  0.1800
# 49     NaN          Drop Breaking                                     NaN
# 50     NaN                    NaN                                     NaN
#
# [51 rows x 30 columns]
# Inkjet DOD                                                                                    28
# Property of Ink                                                                               28
# Ink Hydophobic?                                                                               28
# Nozzle Orifice(um)                                                                            28
# Nozzle Temp(Deg C)                                                                            30
# Jetting Freq(Hz)                                                                              28
# Trise(us)                                                                                     29
# Fall Time(us)                                                                                 31
# Tdwell(optimum)=At velocity max,at optimum Tdwell Voltage is varied to get jettable window    29
# Techo                                                                                         29
# Vmax                                                                                          31
# Vmin                                                                                          31
# Solvent (pressure=(0.01 psi)                                                                   4
# Mol%(l)                                                                                       12
# Mass Loading(%)                                                                                4
# Density(g/ml)(negligible for ML)Dmix = xa * Da + xb * Db=.306*0.0105+.694*.1                   5
# 1.Viscosity(cp)(Most Important Parameter, so give highest weight)                              5
# Surface Tension(mN/m)(effect normalized by Ca-We window)                                       5
# 3.We                                                                                          51
# 4.Ca                                                                                          51
# Solvent Evaporation at nozzle orifice=output5 depends on it                                   51
# Interaction Between Substrate and Impinging Drop                                              51
# Drop's Contact Angle                                                                          51
# Show Coffie ring effect?                                                                      51
# Z=Re/Sqt(We), If<2=not Stable                                                                 51
# Fluid Type                                                                                    29
# Ca                                                                                            49
# We                                                                                            49
# Output1: Drop Quality                                                                         29
# Output2: Velocity of Ejected Drop m/s                                                         40
# dtype: int64
# Shape of Original DataFrame: (51, 30)
# Shape of DataFrame After Dropping All Rows with Missing Values: (0, 30)
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
