# %%
#### Load all types of toronto rooms
# import all modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
# %matplotlib inline
fig1 = plt.figure(figsize=(2, 2), dpi=100)
# %config InlineBackend.figure_format = 'retina'
import datetime
from matplotlib.dates import DateFormatter
from matplotlib.dates import HourLocator
# Import Multiple CSVs and combining them
Total_filepath = "C:/Users/fahmida/Desktop/listings.csv"
df= pd.read_csv(Total_filepath) 

# Import seaborn library
import seaborn as sns

# Get correlation matrix of the meat DataFrame
corr_df = df.corr(method='spearman')
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\ProgramData\Anaconda2\lib\runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "C:\ProgramData\Anaconda2\lib\runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda2\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\kernelapp.py", line 499, in start
# ...

# %%
# Customize the heatmap of the corr_meat correlation matrix
sns.heatmap(corr_df)

plt.xticks(rotation=90)
plt.yticks(rotation=0) 
plt.show()

# %%
import itertools
import copy
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# Grab edge list data hosted on Gist
edgelist = pd.read_csv('C:/Users/fahmida/Desktop/Rental/permanent_network.csv')
edgelist.head(10)
# Out:
#             node1 node2 trail  distance color  estimate
# 0            host  host  host  1.000000   red         0
# 1    accommodates  host  host  0.041329   red         0
# 2       bathrooms  host  host  0.019834   red         0
# 3        bedrooms  host  host -0.016207   red         0
# 4            beds  host  host  0.017895   red         0
# 5           price  host  host  0.061970   red         0
# 6         deposit  host  host  0.125667   red         0
# 7        cleaning  host  host  0.039028   red         0
# 8    extra_people  host  host  0.062835   red         0
# 9  minimum_nights  host  host  0.003318   red         0

# %%
# Grab node list data hosted on Gist
nodelist = pd.read_csv('C:/Users/fahmida/Desktop/edges.csv')

# %%
g = nx.Graph()

# %%
# Add edges and edge attributes
for i, elrow in edgelist.iterrows():
    g.add_edge(elrow[0], elrow[1], attr_dict=elrow[2:].to_dict())

# %%
# Edge list example
print(elrow[0]) # node1
print(elrow[1]) # node2
print(elrow[2:].to_dict()) # edge attribute dict
# Out:
# rating
# rating
# {'color': 'red', 'trail': 'rating', 'estimate': 0L, 'distance': 1.0}

# %%
# Add node attributes
for i, nlrow in nodelist.iterrows():
    g.node[nlrow['id']].update(nlrow[1:].to_dict())

# %%
print(nlrow)
# Out:
# id    rating
# X       1200
# Y        300
# Name: 14, dtype: object

# %%
print('# of edges: {}'.format(g.number_of_edges()))
print('# of nodes: {}'.format(g.number_of_nodes()))
# Out:
# # of edges: 120
# # of nodes: 15

# %%
# Define node positions data structure (dict) for plotting
node_positions = {node[0]: (node[1]['X'], -node[1]['Y']) for node in g.nodes(data=True)}

# Preview of node_positions with a bit of hack (there is no head/slice method for dictionaries).
dict(list(node_positions.items())[0:5])
# Out:
# {'bathrooms': (3164L, -1111L),
#  'bedrooms': (141L, -1938L),
#  'minimum_nights': (2000L, -200L),
#  'price': (4000L, -900L),
#  'rating': (1200L, -300L)}

# %%
print('# of edges: {}'.format(g.edges()))
# Out:
# # of edges: [('rating', 'rating'), ('rating', 'bathrooms'), ('rating', 'minimum_nights'), ('rating', 'price'), ('rating', 'bedrooms'), ('rating', 'extra_people'), ('rating', 'accommodates'), ('rating', 'beds'), ('rating', 'host'), ('rating', 'deposit'), ('rating', 'maximum_nights'), ('rating', 'availability_30'), ('rating', 'availability_365'), ('rating', 'review'), ('rating', 'cleaning'), ('bathrooms', 'bathrooms'), ('bathrooms', 'minimum_nights'), ('bathrooms', 'price'), ('bathrooms', 'bedrooms'), ('bathrooms', 'extra_people'), ('bathrooms', 'accommodates'), ('bathrooms', 'beds'), ('bathrooms', 'host'), ('bathrooms', 'deposit'), ('bathrooms', 'maximum_nights'), ('bathrooms', 'availability_30'), ('bathrooms', 'availability_365'), ('bathrooms', 'review'), ('bathrooms', 'cleaning'), ('minimum_nights', 'minimum_nights'), ('minimum_nights', 'price'), ('minimum_nights', 'bedrooms'), ('minimum_nights', 'extra_people'), ('minimum_nights', 'accommodates'), ('minimum_nights', 'beds'), ('mini
# ...

# %%
# Define data structure (list) of edge colors for plotting
edge_colors = edgelist['color'].tolist()
print(edge_colors)

print("dfToList is", edge_colors, "and it's a", type(edge_colors))
# Out:
# ['red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 're
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from([('rating', 'rating'), ('rating', 'bathrooms'), ('rating', 'minimum_nights'), ('rating', 'price'), ('rating', 'bedrooms'), ('rating', 'extra_people'), ('rating', 'accommodates'), ('rating', 'beds'), ('rating', 'host'), ('rating', 'deposit'), ('rating', 'maximum_nights'), ('rating', 'availability_30'), ('rating', 'availability_365'), ('rating', 'review'), ('rating', 'cleaning'), ('bathrooms', 'bathrooms'), ('bathrooms', 'minimum_nights'), ('bathrooms', 'price'), ('bathrooms', 'bedrooms'), ('bathrooms', 'extra_people'), ('bathrooms', 'accommodates'), ('bathrooms', 'beds'), ('bathrooms', 'host'), ('bathrooms', 'deposit'), ('bathrooms', 'maximum_nights'), ('bathrooms', 'availability_30'), ('bathrooms', 'availability_365'), ('bathrooms', 'review'), ('bathrooms', 'cleaning'), ('minimum_nights', 'minimum_nights'), ('minimum_nights', 'price'), ('minimum_nights', 'bedrooms'), ('minimum_nights', 'extra_people'), ('minimum_nights', 'accommodates'), ('minimum_nights', 'beds'), ('minimum_nights', 'host'), ('minimum_nights', 'deposit'), ('minimum_nights', 'maximum_nights'), ('minimum_nights', 'availability_30'), ('minimum_nights', 'availability_365'), ('minimum_nights', 'review'), ('minimum_nights', 'cleaning'), ('price', 'price'), ('price', 'bedrooms'), ('price', 'extra_people'), ('price', 'accommodates'), ('price', 'beds'), ('price', 'host'), ('price', 'deposit'), ('price', 'maximum_nights'), ('price', 'availability_30'), ('price', 'availability_365'), ('price', 'review'), ('price', 'cleaning'), ('bedrooms', 'bedrooms'), ('bedrooms', 'extra_people'), ('bedrooms', 'accommodates'), ('bedrooms', 'beds'), ('bedrooms', 'host'), ('bedrooms', 'deposit'), ('bedrooms', 'maximum_nights'), ('bedrooms', 'availability_30'), ('bedrooms', 'availability_365'), ('bedrooms', 'review'), ('bedrooms', 'cleaning'), ('extra_people', 'extra_people'), ('extra_people', 'accommodates'), ('extra_people', 'beds'), ('extra_people', 'host'), ('extra_people', 'deposit'), ('extra_people', 'maximum_nights'), ('extra_people', 'availability_30'), ('extra_people', 'availability_365'), ('extra_people', 'review'), ('extra_people', 'cleaning'), ('accommodates', 'accommodates'), ('accommodates', 'beds'), ('accommodates', 'host'), ('accommodates', 'deposit'), ('accommodates', 'maximum_nights'), ('accommodates', 'availability_30'), ('accommodates', 'availability_365'), ('accommodates', 'review'), ('accommodates', 'cleaning'), ('beds', 'beds'), ('beds', 'host'), ('beds', 'deposit'), ('beds', 'maximum_nights'), ('beds', 'availability_30'), ('beds', 'availability_365'), ('beds', 'review'), ('beds', 'cleaning'), ('host', 'host'), ('host', 'deposit'), ('host', 'maximum_nights'), ('host', 'availability_30'), ('host', 'availability_365'), ('host', 'review'), ('host', 'cleaning'), ('deposit', 'deposit'), ('deposit', 'maximum_nights'), ('deposit', 'availability_30'), ('deposit', 'availability_365'), ('deposit', 'review'), ('deposit', 'cleaning'), ('maximum_nights', 'maximum_nights'), ('maximum_nights', 'availability_30'), ('maximum_nights', 'availability_365'), ('maximum_nights', 'review'), ('maximum_nights', 'cleaning'), ('availability_30', 'availability_30'), ('availability_30', 'availability_365'), ('availability_30', 'review'), ('availability_30', 'cleaning'), ('availability_365', 'availability_365'), ('availability_365', 'review'), ('availability_365', 'cleaning'), ('review', 'review'), ('review', 'cleaning'), ('cleaning', 'cleaning')])
val_map = {'host': 1,
           'accommodates':0.04132905,
           'bathrooms': 0.019834114,
           'bedrooms': -0.016207443,
           'beds': 0.01789497,
           'price':0.061970317,
           'deposit':0.125667464,
           'cleaning':0.039028043,
           'extra_people':0.06283462,
            'minimum_nights':0.003318156,
            'maximum_nights':-0.039580408,
            'availability_30':-0.082049172,
           'availability_365':-0.013952571,
           'review':0.342749381,
           'rating':0.291807052       
          }

values = [val_map.get(node,0.001) for node in G.nodes()]

# Specify the edges you want here
red_edges = [('price', 'host'),('price', 'accommodates'),('price', 'bathrooms'),('price', 'bedrooms'),('price', 'beds'),('price', 'deposit'),('price', 'cleaning'),('price', 'extra_people'),('price', 'minimum_nights'),
             ('price', 'maximum_nights'),('price', 'availability_30'),('price', 'availability_365'),('price', 'review'),('price', 'rating')]
edge_colours = ['black' if not edge in red_edges else 'red'
                for edge in G.edges()]
black_edges = [edge for edge in G.edges() if edge not in red_edges]

# Need to create a layout when doing
# separate calls to draw nodes and edges
pos = nx.spring_layout(G)
plt.figure(figsize=(15, 10))
nx.draw_networkx_nodes(G, pos, cmap=plt.get_cmap('jet'), 
                       node_color = values, node_size = 1500)
nx.draw_networkx_labels(G, pos)
nx.draw_networkx_edges(G, pos, edgelist=red_edges, edge_color='r', arrows=True)
nx.draw_networkx_edges(G, pos, edgelist=black_edges, arrows=False)

plt.title('Graphical Similarity of Airbnb Features', size=15)
plt.show()
